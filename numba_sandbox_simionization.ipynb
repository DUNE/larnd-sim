# %%
import numpy as np
import pandas as pd
import time
import timeit
from numba import cuda
from numba import vectorize
import math
import consts

# %%
'''GPU Quenching Kernel function'''
@cuda.jit
def Quenching(x_start,x_end,y_start,y_end,z_start,z_end,dE, nElectrons):
    pos  = cuda.grid(1)         
    if (pos < x_start.shape[0]):   
        dx         = math.sqrt((x_end[pos] - x_start[pos]) ** 2 + 
                    (y_end[pos] - y_start[pos]) ** 2 +
                    (z_end[pos] - z_start[pos]) ** 2)
        dedx        = abs(dE[pos])*consts.GeVToMeV/dx
        epsilon     = consts.recombBeta/(consts.lArDensity * consts.eField) * dedx
        recomb      = math.log(consts.recombAlpha + epsilon) / epsilon
        
        nElectrons[pos]  = recomb * dE[pos] * consts.GeVToMeV * consts.MeVToElectrons

# %%
'''GPU Drift Simulation Kernel function'''
@cuda.jit
def Drifting(z_start, z_end, nElectrons,long_diffusion, trans_diffusion):
    pos  = cuda.grid(1)    
    if (pos < z_start.shape[0]): 
        z = (z_end[pos] + z_start[pos])/2.    
        drift_time  = abs(z - consts.tpcPlaneZ)/ consts.vdrift;
        lifetime    = math.exp(-drift_time/consts.msTous)
        nElectrons[pos]      *= lifetime
        long_diffusion[pos]  = math.sqrt(drift_time) * consts.longDiff
        trans_diffusion[pos] = math.sqrt(drift_time) * consts.transDiff

# %%
'Read input file and copy arrays to device memory'

tracks = pd.read_csv('tracks.txt', delim_whitespace=True)

'Input Arrays'
x_start_device = cuda.to_device(tracks['x_start'].to_numpy())
x_end_device   = cuda.to_device(tracks['x_end'].to_numpy())
y_start_device = cuda.to_device(tracks['y_start'].to_numpy())
y_end_device   = cuda.to_device(tracks['y_end'].to_numpy())
z_start_device = cuda.to_device(tracks['z_start'].to_numpy())
z_end_device   = cuda.to_device(tracks['z_end'].to_numpy())
dE_device      = cuda.to_device(tracks['dE'].to_numpy())

'Output Arrays'
long_diffusion_device  = cuda.device_array_like(x_start_device)
trans_diffusion_device = cuda.device_array_like(x_start_device)
nelec_device           = cuda.device_array_like(x_start_device)

# %%
threads_per_block = 128
blocks_per_grid   = 30

# %%
# %%time
Quenching[blocks_per_grid, threads_per_block](x_start_device,
                                              x_end_device,
                                              y_start_device,
                                              y_end_device,
                                              z_start_device,
                                              z_end_device,
                                              dE_device,
                                              nelec_device)
# Out:
# CPU times: user 206 ms, sys: 4.37 ms, total: 211 ms
# Wall time: 215 ms

# %%
# %%timeit -n1000
Quenching[blocks_per_grid, threads_per_block](x_start_device,
                                              x_end_device,
                                              y_start_device,
                                              y_end_device,
                                              z_start_device,
                                              z_end_device,
                                              dE_device,
                                              nelec_device)
# Out:
# 257 µs ± 4.75 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%time
Drifting[blocks_per_grid, threads_per_block](z_start_device, 
                                             z_end_device, 
                                             nelec_device, 
                                             long_diffusion_device,
                                             trans_diffusion_device)
# Out:
# CPU times: user 157 ms, sys: 273 µs, total: 157 ms
# Wall time: 157 ms

# %%
# %%timeit -n1000
Drifting[blocks_per_grid, threads_per_block](z_start_device, 
                                             z_end_device, 
                                             nelec_device, 
                                             long_diffusion_device,
                                             trans_diffusion_device)
# Out:
# 191 µs ± 3.85 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%time
tracks['long_diffusion']   = long_diffusion_device.copy_to_host()
tracks['trans_diffusion']  = trans_diffusion_device.copy_to_host()
tracks['nElectrons']       = nelec_device.copy_to_host()
# Out:
# CPU times: user 3.29 ms, sys: 0 ns, total: 3.29 ms
# Wall time: 2.69 ms

# %%
tracks[:20]
# Out:
#     track_id    x_start      x_end    y_start      y_end    z_start  \
# 0          0  34.838947  34.675339 -47.529610 -47.650214  72.756482
# 1          0  34.675339  34.175492 -47.650214 -48.018983  72.835971
# 2          0  34.175492  33.734543 -48.018983 -48.344365  73.079805
# 3          0  33.734543  30.876980 -48.344365 -50.428987  73.294425
# 4          0  30.876980  30.752687 -50.428987 -50.519585  74.691796
# 5          0  30.752687  30.154558 -50.519585 -50.954800  74.752716
# 6          0  30.154558  30.020936 -50.954800 -51.052066  75.044250
# 7          0  30.020936  29.604457 -51.052066 -51.355745  75.109381
# 8          0  29.604457  29.106617 -51.355745 -51.718589  75.312549
# 9          0  29.106617  28.866414 -51.718589 -51.894283  75.555749
# 10         0  28.866414  28.614683 -51.894283 -52.078852  75.673400
# 11         0  28.614683  27.248294 -52.078852 -53.081058  75.796400
# 12         0  27.248294  26.248316 -53.081058 -53.802854  76.462512
# 13         0  26.248316  25.823331 -53.802854 -54.110980  76.954270
# 14         0  25.823331  24.685854 -54.110980 -54.933345  77.166192
# 15         0  24.685854  24.467909 -54.933345 -55.090714  77.733519
# 16         0  24.467909  24.310484 -55.090714 -55.204476  77.841402
# 17         0  24.310484  23.191887 -55.204476 -56.015553  77.919148
# 18         0  23.191887  22.386454 -56.015553 -56.602189  78.467655
# 19         0  22.386454  21.894086 -56.602189 -56.957939  78.860446
#
#         z_end        dE  long_diffusion  trans_diffusion     nElectrons
# 0   72.835971  0.000417        0.000236         0.000620   10858.415074
# 1   73.079805  0.001360        0.000236         0.000621   35196.815115
# 2   73.294425  0.001391        0.000236         0.000621   35416.259371
# 3   74.691796  0.007353        0.000237         0.000622  191033.631305
# 4   74.752716  0.000294        0.000237         0.000623    7672.890095
# 5   75.044250  0.001390        0.000237         0.000623   36305.065281
# 6   75.109381  0.000280        0.000237         0.000624    7323.485586
# 7   75.312549  0.000969        0.000237         0.000624   25303.687427
# 8   75.555749  0.001201        0.000237         0.000624   31313.765541
# 9   75.673400  0.000647        0.000237         0.000624   16734.064153
# 10  75.796400  0.000582        0.000238         0.000624   15188.519103
# 11  76.462512  0.003412        0.000238         0.000625   88723.924357
# 12  76.954270  0.002412        0.000238         0.000626   62821.354674
# 13  77.166192  0.001330        0.000238         0.000626   33811.657688
# 14  77.733519  0.002812        0.000238         0.000627   73086.272181
# 15  77.841402  0.000480        0.000239         0.000627   12543.474876
# 16  77.919148  0.000357        0.000239         0.000627    9324.139844
# 17  78.467655  0.002968        0.000239         0.000628   76709.124165
# 18  78.860446  0.002358        0.000239         0.000628   60329.025226
# 19  79.099661  0.001133        0.000239         0.000629   29539.868553
